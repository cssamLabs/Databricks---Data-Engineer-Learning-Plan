# %% [markdown]
# # Automated Deployment with Databricks Asset Bundles

# %% [markdown]
# ## DevOps and CI/CD Review
#
# ### DevOps Review
#
# ![automated-deployment-devops-review-ci-cd](images/automated-deployment-devops-review-ci-cd.png)
# ![automated-deployment-devops-review-ci-cd-objectives](images/automated-deployment-devops-review-ci-cd-objectives.png)
# ![automated-deployment-devops-review-ci-cd-what](images/automated-deployment-devops-review-ci-cd-what.png)
# ![automated-deployment-devops-review-ci-cd-processes](images/automated-deployment-devops-review-ci-cd-processes.png)
# ![automated-deployment-devops-review-dtatops-mlops](images/automated-deployment-devops-review-dtatops-mlops.png)
# ![automated-deployment-devops-review-dataops](images/automated-deployment-devops-review-dataops.png)
#
# ### Continuous Integration and Continuous Deployment
# ![automated-deployment-ci-cd-review](images/automated-deployment-ci-cd-review.png)
# ![automated-deployment-ci-cd-review-role](images/automated-deployment-ci-cd-review-role.png)
# ![automated-deployment-ci-cd-review-overview](images/automated-deployment-ci-cd-review-overview.png)
# ![automated-deployment-ci-cd-review-tools](images/automated-deployment-ci-cd-review-tools.png)
# ![automated-deployment-ci-cd-review-cli](images/automated-deployment-ci-cd-review-cli.png)

# %% [markdown]
# ## Deployment with Databricks Assets Bundles (DBAs)
# ![automated-deployment-assets-bundles](images/automated-deployment-assets-bundles.png)
# ![automated-deployment-assets-bundles-objective](images/automated-deployment-assets-bundles-objectives.png)
#
# ### Deploying Databricks Projects
# ![automated-deployment-assets-bundles-deploying](images/automated-deployment-assets-bundles-deploying.png)
# ![automated-deployment-assets-bundles-deploying-typical-projects](images/automated-deployment-assets-bundles-deploying-typical-projects.png)
# ![automated-deployment-assets-bundles-deploying-project-components](images/automated-deployment-assets-bundles-deploying-project-components.png)
# ![automated-deployment-assets-bundles-deploying-ci-cd-journey](images/automated-deployment-assets-bundles-deploying-ci-cd-journey.png)
# ![automated-deployment-assets-bundles-deploying-ci-cd-journey-config](images/automated-deployment-assets-bundles-deploying-ci-cd-journey-config.png)
# ![automated-deployment-assets-bundles-deploying-ci-cd-journey-orchestrate](images/automated-deployment-assets-bundles-deploying-ci-cd-journey-orchestrate.png)
# ![automated-deployment-assets-bundles-deploying-ci-cd-process-simplifying](images/automated-deployment-assets-bundles-deploying-ci-cd-process-simplifying.png)
# ![automated-deployment-assets-bundles-deploying-dab-introducing](images/automated-deployment-assets-bundles-deploying-dab-introducing.png)
#
# ### Introduction to Databricks Asset Bundles (DABs)
# ![automated-deployment-assets-bundles-deploying-introduction](images/automated-deployment-assets-bundles-deploying-introduction.png)
# ![automated-deployment-assets-bundles-deploying-introduction-basics](images/automated-deployment-assets-bundles-deploying-introduction-basics.png)
# ![automated-deployment-assets-bundles-deploying-introduction-ci-cd-overview](images/automated-deployment-assets-bundles-deploying-introduction-ci-cd-overview.png)
# ![automated-deployment-assets-bundles-deploying-introduction-simple-project-structure](images/automated-deployment-assets-bundles-deploying-introduction-simple-project-structure.png)
# ![automated-deployment-assets-bundles-deploying-introduction-simple-project-structure-yaml](images/automated-deployment-assets-bundles-deploying-introduction-simple-project-structure-yaml.png)
# ![automated-deployment-assets-bundles-deploying-introduction-yaml-mappings](images/automated-deployment-assets-bundles-deploying-introduction-yaml-mappings.png)
# ![automated-deployment-assets-bundles-deploying-introduction-yaml-bundle](images/automated-deployment-assets-bundles-deploying-introduction-yaml-bundle.png)
# ![automated-deployment-assets-bundles-deploying-introduction-yaml-resources](images/automated-deployment-assets-bundles-deploying-introduction-yaml-resources.png)
# ![automated-deployment-assets-bundles-deploying-introduction-yaml-targets](images/automated-deployment-assets-bundles-deploying-introduction-yaml-targets.png)
# ![automated-deployment-assets-bundles-deploying-introduction-cli-validate](images/automated-deployment-assets-bundles-deploying-introduction-cli-validate.png)
# ![automated-deployment-assets-bundles-deploying-introduction-cli-deploy](images/automated-deployment-assets-bundles-deploying-introduction-cli-deploy.png)
# ![automated-deployment-assets-bundles-deploying-introduction-cli-run](images/automated-deployment-assets-bundles-deploying-introduction-cli-run.png)
#
#
# ### Variable Substitutions
# ![automated-deployment-assets-bundles-deploying-variable-substitutions](images/automated-deployment-assets-bundles-deploying-variable-substitutions.png)
# ![automated-deployment-assets-bundles-deploying-variable-substitutions-overview](images/automated-deployment-assets-bundles-deploying-variable-substitutions-overview.png)
# ![automated-deployment-assets-bundles-deploying-variable-substitutions-simple-custom-variables](images/automated-deployment-assets-bundles-deploying-variable-substitutions-simple-custom-variables.png)
# ![automated-deployment-assets-bundles-deploying-variable-substitutions-complex-custom-variables](images/automated-deployment-assets-bundles-deploying-variable-substitutions-complex-custom-variables.png)
# ![automated-deployment-assets-bundles-deploying-variable-substitutions-lookup-variables](images/automated-deployment-assets-bundles-deploying-variable-substitutions-lookup-variables.png)
# ![automated-deployment-assets-bundles-deploying-variable-substitutions-lookup-variables-defaults](images/automated-deployment-assets-bundles-deploying-variable-substitutions-lookup-variables-defaults.png)
# ![automated-deployment-assets-bundles-deploying-variable-substitutions-variables-overrides](images/automated-deployment-assets-bundles-deploying-variable-substitutions-variables-overrides.png)
# ![automated-deployment-assets-bundles-deploying-variable-substitutions-variables-benefits](images/automated-deployment-assets-bundles-deploying-variable-substitutions-variables-benefits.png)
#
#
# ### Variable Substitutions - Lab -  Deploying a Simple DAB
#
# ![automated-deployment-assets-bundles-deploying-lab1-code-1](images/automated-deployment-assets-bundles-deploying-lab1-code-1.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-2](images/automated-deployment-assets-bundles-deploying-lab1-code-2.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-3](images/automated-deployment-assets-bundles-deploying-lab1-code-3.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-4](images/automated-deployment-assets-bundles-deploying-lab1-code-4.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-5](images/automated-deployment-assets-bundles-deploying-lab1-code-5.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-6](images/automated-deployment-assets-bundles-deploying-lab1-code-6.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-7](images/automated-deployment-assets-bundles-deploying-lab1-code-7.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-8](images/automated-deployment-assets-bundles-deploying-lab1-code-8.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-9](images/automated-deployment-assets-bundles-deploying-lab1-code-9.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-10](images/automated-deployment-assets-bundles-deploying-lab1-code-10.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-11](images/automated-deployment-assets-bundles-deploying-lab1-code-11.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-12](images/automated-deployment-assets-bundles-deploying-lab1-code-12.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-13](images/automated-deployment-assets-bundles-deploying-lab1-code-13.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-14](images/automated-deployment-assets-bundles-deploying-lab1-code-14.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-15](images/automated-deployment-assets-bundles-deploying-lab1-code-15.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-16](images/automated-deployment-assets-bundles-deploying-lab1-code-16.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-17](images/automated-deployment-assets-bundles-deploying-lab1-code-17.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-18](images/automated-deployment-assets-bundles-deploying-lab1-code-18.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-19](images/automated-deployment-assets-bundles-deploying-lab1-code-19.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-20](images/automated-deployment-assets-bundles-deploying-lab1-code-20.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-21](images/automated-deployment-assets-bundles-deploying-lab1-code-21.png)
# ![automated-deployment-assets-bundles-deploying-lab1-code-22](images/automated-deployment-assets-bundles-deploying-lab1-code-22.png)
#
#
# ### Variable Substitutions - Lab -  Deploying a Multiple Environments DAB
# ![automated-deployment-assets-bundles-deploying-lab2-code-1](images/automated-deployment-assets-bundles-deploying-lab2-code-1.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-2](images/automated-deployment-assets-bundles-deploying-lab2-code-2.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-3](images/automated-deployment-assets-bundles-deploying-lab2-code-3.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-4](images/automated-deployment-assets-bundles-deploying-lab2-code-4.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-5](images/automated-deployment-assets-bundles-deploying-lab2-code-5.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-6](images/automated-deployment-assets-bundles-deploying-lab2-code-6.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-7](images/automated-deployment-assets-bundles-deploying-lab2-code-7.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-8](images/automated-deployment-assets-bundles-deploying-lab2-code-8.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-9](images/automated-deployment-assets-bundles-deploying-lab2-code-9.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-10](images/automated-deployment-assets-bundles-deploying-lab2-code-10.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-11](images/automated-deployment-assets-bundles-deploying-lab2-code-11.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-12](images/automated-deployment-assets-bundles-deploying-lab2-code-12.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-13](images/automated-deployment-assets-bundles-deploying-lab2-code-13.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-14](images/automated-deployment-assets-bundles-deploying-lab2-code-14.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-15](images/automated-deployment-assets-bundles-deploying-lab2-code-15.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-16](images/automated-deployment-assets-bundles-deploying-lab2-code-16.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-17](images/automated-deployment-assets-bundles-deploying-lab2-code-17.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-18](images/automated-deployment-assets-bundles-deploying-lab2-code-18.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-19](images/automated-deployment-assets-bundles-deploying-lab2-code-19.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-20](images/automated-deployment-assets-bundles-deploying-lab2-code-20.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-21](images/automated-deployment-assets-bundles-deploying-lab2-code-21.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-22](images/automated-deployment-assets-bundles-deploying-lab2-code-22.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-23](images/automated-deployment-assets-bundles-deploying-lab2-code-23.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-24](images/automated-deployment-assets-bundles-deploying-lab2-code-24.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-25](images/automated-deployment-assets-bundles-deploying-lab2-code-25.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-26](images/automated-deployment-assets-bundles-deploying-lab2-code-26.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-27](images/automated-deployment-assets-bundles-deploying-lab2-code-27.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-28](images/automated-deployment-assets-bundles-deploying-lab2-code-28.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-29](images/automated-deployment-assets-bundles-deploying-lab2-code-29.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-30](images/automated-deployment-assets-bundles-deploying-lab2-code-30.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-31](images/automated-deployment-assets-bundles-deploying-lab2-code-31.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-32](images/automated-deployment-assets-bundles-deploying-lab2-code-32.png)
# ![automated-deployment-assets-bundles-deploying-lab2-code-33](images/automated-deployment-assets-bundles-deploying-lab2-code-33.png)

# %% [markdown]
# ### DAB Project Templates Overview
#
# ![automated-deployment-DAB-templates](images/automated-deployment-DAB-templates.png)
# ![automated-deployment-DAB-templates-description](images/automated-deployment-DAB-templates-description.png)
#
#
# ### CI/CD Project Overview with DABs
# ![automated-deployment-DAB-ci-cd](images/automated-deployment-DAB-ci-cd.png)
# ![automated-deployment-DAB-ci-cd-project-planning](images/automated-deployment-DAB-ci-cd-project-planning.png)
# ![automated-deployment-DAB-ci-cd-project-architecture](images/automated-deployment-DAB-ci-cd-project-architecture.png)
# ![automated-deployment-DAB-unit-testing-pytest](images/automated-deployment-DAB-unit-testing-pytest.png)
# ![automated-deployment-DAB-integration-tests](images/automated-deployment-DAB-integration-tests.png)
#
#
# ### Demo
# ![automated-deployment-DAB-code-1](images/automated-deployment-DAB-code-1.png)
# ![automated-deployment-DAB-code-2](images/automated-deployment-DAB-code-2.png)
# ![automated-deployment-DAB-code-3](images/automated-deployment-DAB-code-3.png)
# ![automated-deployment-DAB-code-4](images/automated-deployment-DAB-code-4.png)
# ![automated-deployment-DAB-code-5](images/automated-deployment-DAB-code-5.png)
# ![automated-deployment-DAB-code-6](images/automated-deployment-DAB-code-6.png)
# ![automated-deployment-DAB-code-7](images/automated-deployment-DAB-code-7.png)
# ![automated-deployment-DAB-code-8](images/automated-deployment-DAB-code-8.png)
# ![automated-deployment-DAB-code-9](images/automated-deployment-DAB-code-9.png)
# ![automated-deployment-DAB-code-10](images/automated-deployment-DAB-code-10.png)
# ![automated-deployment-DAB-code-11](images/automated-deployment-DAB-code-11.png)
# ![automated-deployment-DAB-code-12](images/automated-deployment-DAB-code-12.png)
# ![automated-deployment-DAB-code-13](images/automated-deployment-DAB-code-13.png)
# ![automated-deployment-DAB-code-14](images/automated-deployment-DAB-code-14.png)
# ![automated-deployment-DAB-code-15](images/automated-deployment-DAB-code-15.png)
# ![automated-deployment-DAB-code-16](images/automated-deployment-DAB-code-16.png)
# ![automated-deployment-DAB-code-17](images/automated-deployment-DAB-code-17.png)
# ![automated-deployment-DAB-code-18](images/automated-deployment-DAB-code-18.png)
# ![automated-deployment-DAB-code-19](images/automated-deployment-DAB-code-19.png)
# ![automated-deployment-DAB-code-20](images/automated-deployment-DAB-code-20.png)
# ![automated-deployment-DAB-code-21](images/automated-deployment-DAB-code-21.png)

# %% [markdown]
# ## Doing More with DABs
# ![automated-deployment-doing-more-with-DABs](images/automated-deployment-doing-more-with-DABs.png)
# ![automated-deployment-doing-more-with-DABs-objectives](images/automated-deployment-doing-more-with-DABs-objectives.png)

# %% [markdown]
# ### Developing Locally with Visual Studio Code (VSCode)
# ![automated-deployment-vscode](images/automated-deployment-vscode.png)
# ![automated-deployment-vscode-tools](images/automated-deployment-vscode-tools.png)
# ![automated-deployment-vscode-databrickes-extension](images/automated-deployment-vscode-databrickes-extension.png)
# ![automated-deployment-vscode-code-1](images/automated-deployment-vscode-code-1.png)
# ![automated-deployment-vscode-code-2](images/automated-deployment-vscode-code-2.png)
# ![automated-deployment-vscode-code-3](images/automated-deployment-vscode-code-3.png)
# ![automated-deployment-vscode-code-4](images/automated-deployment-vscode-code-4.png)
# ![automated-deployment-vscode-code-5](images/automated-deployment-vscode-code-5.png)
# ![automated-deployment-vscode-code-6](images/automated-deployment-vscode-code-6.png)
# ![automated-deployment-vscode-code-7](images/automated-deployment-vscode-code-7.png)
# ![automated-deployment-vscode-code-8](images/automated-deployment-vscode-code-8.png)
# ![automated-deployment-vscode-code-9](images/automated-deployment-vscode-code-9.png)
# ![automated-deployment-vscode-code-10](images/automated-deployment-vscode-code-10.png)
# ![automated-deployment-vscode-code-11](images/automated-deployment-vscode-code-11.png)

# %% [markdown]
# ### CI/CD Best Practices for Data Engineering
# ![automated-deployment-ci-cd-patterns](images/automated-deployment-ci-cd-patterns.png)
